# %% [markdown]
# # Jupyter Notebook
# #### Intro...

# %% [markdown]
# **Ganesh Jogi**

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
print('My name is Ganesh...')
# Out:
# My name is Ganesh...

# %%
li = "ganesh"
print(li[::-1])
# Out:
# hsenag
