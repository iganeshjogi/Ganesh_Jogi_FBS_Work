# %% [markdown]
# #### Introduction
#
# 1. Scientific computing library
# 2. Numeric Python
# 3. Written in C and Python
# 4. Support the multidimensional array, matrix
# 5. pip install numpy
# 6. import numpy as np

# %%
# %%time
li1 = list(range(1, 100001))
li2 = list(range(1, 100001))

li3 = []

for i,j in zip(li1, li2):
    li3.append(i + j)
# print(li3)
# Out:
# CPU times: total: 46.9 ms
# Wall time: 78.2 ms

# %%
import numpy as np

# %%
# %%time
arr1 = np.arange(1, 100001)
arr2 = np.arange(1, 100001)
res = arr1 + arr2
# Out:
# CPU times: total: 0 ns
# Wall time: 1.59 ms
