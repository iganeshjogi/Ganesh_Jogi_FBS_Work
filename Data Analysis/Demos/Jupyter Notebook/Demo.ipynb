# %%
import numpy as np

# %%
matrix = np.array([[1, 2, 3], [4, 5, 6]])

# %%
matrix
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
matrix[0]
# Out:
# array([1, 2, 3])

# %%
matrix[1]
# Out:
# array([4, 5, 6])

# %%
matrix[:]
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
matrix[::-1]
# Out:
# array([[4, 5, 6],
#        [1, 2, 3]])

# %%
matrix[1][0]
