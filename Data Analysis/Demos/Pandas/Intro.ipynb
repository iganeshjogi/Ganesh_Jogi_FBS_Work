# %% [markdown]
# # Pandas

# %% [markdown]
# ## Introduction
# 1. Powerful toolkit for data analysis
# 2. Have data structures (Series, Dataframe, Panel)
# 3. Reading & writing data structure, and different file formats (CSV, TSV, Excel)

# %% [markdown]
# ## Data Structure
# 1. Series (1D)
# 2. Dataframe (2D)
# 3. Panel (3D)
