# %%
import pandas as pd

# %%
s1 = pd.Series([10, 20, 30, 40, 50])
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s1 = pd.Series([10, 20, 30, 40, 50], index=['a', 'b', 'c', 'd', 'e'])
s1
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
s2 = pd.Series([60, 70, 80, 90, 100], index=['c', 'd', 'e', 'f', 'g'])
s2
# Out:
# c     60
# d     70
# e     80
# f     90
# g    100
# dtype: int64

# %%
s1 + s2
# Out:
# a      NaN
# b      NaN
# c     90.0
# d    110.0
# e    130.0
# f      NaN
# g      NaN
# dtype: float64

# %%
s1.min()
# Out:
# np.int64(10)

# %%
s1.max()
# Out:
# np.int64(50)

# %%
s1.mean()
# Out:
# np.float64(30.0)

# %%
s1.mode()
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s1.median()
# Out:
# np.float64(30.0)
