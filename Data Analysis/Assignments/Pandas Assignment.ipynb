# %% [markdown]
# # Pandas Assignment

# %%
import pandas as pd

# %% [markdown]
# ## Q1. Refer to googleplaystore.csv file and solve following questions.

# %%
data = pd.read_csv("C:/Users/ganes/OneDrive/Desktop/FBS/Database files/googleplaystore.csv")

# %% [markdown]
# ### a. Display First 5 records from Dataframe.

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# ### b. Display category with highest number of apps registered.

# %%
data['Category'].value_counts().idxmax()
# Out:
# 'FAMILY'

# %% [markdown]
# ### c. What is the average rating for all the apps

# %%
data['Rating'].mean()
# Out:
# np.float64(4.193338315362443)

# %% [markdown]
# ### d. Display total number of apps which even supports Andriod version 2.3 and up

# %%
len(data[data['Android Ver'] == '2.3 and up'])
# Out:
# 652

# %% [markdown]
# ### e. Impute the missing values available in rating column with respective measure of central tendency.

# %%
data['Rating'] = data['Rating'].fillna(data['Rating'].mean())
data['Rating']
# Out:
# 0        4.100000
# 1        3.900000
# 2        4.700000
# 3        4.500000
# 4        4.300000
#            ...
# 10836    4.500000
# 10837    5.000000
# 10838    4.193338
# 10839    4.500000
# 10840    4.500000
# Name: Rating, Length: 10841, dtype: float64

# %% [markdown]
# ## Q2. Refer to salaries.xlsx file and solve following questions

# %%
dt = pd.read_excel("C:/Users/ganes/OneDrive/Desktop/FBS/Database files/Salaries.xlsx")

# %% [markdown]
# ### a. Check head of the dataframe

# %%
dt.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN
# 3  2011    NaN  San Francisco     NaN
# 4  2011    NaN  San Francisco     NaN

# %% [markdown]
# ### b. Find out details about no. of entries & no. of columns in the data frame

# %%
dt.shape
# Out:
# (1000, 13)

# %% [markdown]
# ### c. What is the average base pay?

# %%
dt['BasePay'].mean()
# Out:
# np.float64(145663.9982)

# %% [markdown]
# ### d. What is the highest amount of overtime pay in the dataset?

# %%
dt['OvertimePay'].max()
# Out:
# np.float64(245131.88)

# %% [markdown]
# ### e. What is the job title of JOSEPH DRISCOLL?

# %%
dt.loc[dt['EmployeeName'] == 'JOSEPH DRISCOLL',['EmployeeName', 'JobTitle']]
# Out:
#         EmployeeName                                        JobTitle
# 0    JOSEPH DRISCOLL  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1    JOSEPH DRISCOLL                 CAPTAIN III (POLICE DEPARTMENT)
# 2    JOSEPH DRISCOLL                 CAPTAIN III (POLICE DEPARTMENT)
# 3    JOSEPH DRISCOLL            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    JOSEPH DRISCOLL    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ..               ...                                             ...
# 995  JOSEPH DRISCOLL                       CLINICAL NURSE SPECIALIST
# 996  JOSEPH DRISCOLL                       CLINICAL NURSE SPECIALIST
# 997  JOSEPH DRISCOLL                       CLINICAL NURSE SPECIALIST
# 998  JOSEPH DRISCOLL                       CLINICAL NURSE SPECIALIST
# 999  JOSEPH DRISCOLL                       CLINICAL NURSE SPECIALIST
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### f. How much does JOSEPH DRISCOLL make (including benefits)?

# %%
dt.loc[dt['EmployeeName'] == 'JOSEPH DRISCOLL',['TotalPayBenefits']]
# Out:
#      TotalPayBenefits
# 0           567595.43
# 1           538909.28
# 2           335279.91
# 3           332343.61
# 4           326373.19
# ..                ...
# 995         169822.08
# 996         169822.06
# 997         169822.05
# 998         169822.01
# 999         169822.00
#
# [1000 rows x 1 columns]

# %% [markdown]
# ### g. How many unique job titles are there?

# %%
dt['JobTitle'].nunique()
# Out:
# 113

# %% [markdown]
# ### h. What are the top 5 common jobs?

# %%
dt['JobTitle'].value_counts()[0:5]
# Out:
# JobTitle
# FIREFIGHTER                           133
# LIEUTENANT, FIRE DEPARTMENT            62
# FIRE FIGHTER PARAMEDIC                 43
# CAPTAIN, FIRE SUPPRESSION              42
# BATTALION CHIEF, (FIRE DEPARTMENT)     41
# Name: count, dtype: int64
